# %%
import pandas as pd
import numpy as np
from os import getcwd
from os.path import join

# %%
DIRECTORY = getcwd()
DIRECTORY
# Out:
# 'C:\\Users\\conf\\Desktop\\agnia'

# %% [markdown]
# # Путь до директории, в которой лежит ноутбук, вычисляется самостоятельно
# # Необходимо указать лишь имя файла (в переменной dataset_name)

# %%
dataset_name = "rdp_16s_v18.fa.dat"
dataset_path = join(DIRECTORY, dataset_name)

# %%
with open(dataset_path, encoding='utf-8', newline='\r\n') as f:
    line = f.readline().split('\t')
    columns_count, rows_count = int(line[0]), int(line[1])
    columns_type = [next(f).split() for _ in range(columns_count)]
column_to_type = dict(columns_type)

# %% [markdown]
# # 'Domain' - Домен
# # 'Phylum' - Тип
# # 'Class' - Класс
# # 'Order' - Порядок
# # 'Family' - Семейство
# # 'Genus' - Род

# %%
headers = list(column_to_type.keys())

# %% [markdown]
# # Выбираем столбцы, по которым будет осуществляться группировка

# %%
groups_key = headers[2:5]
groups_key
# Out:
# ['Phylum', 'Class', 'Order']

# %%
df = pd.read_csv(dataset_path, delimiter="\t", names=headers, skiprows=columns_count+1)

# %% [markdown]
# # Исходный датасет

# %%
df
# Out:
#               ID    Domain          Phylum                Class  \
# 0       AJ000684  Bacteria  Actinobacteria       Actinobacteria
# 1       EF599163  Bacteria  Proteobacteria  Gammaproteobacteria
# 2       AY859683  Bacteria  Actinobacteria       Actinobacteria
# 3       AY883036  Bacteria  Proteobacteria  Alphaproteobacteria
# 4       DQ656489  Bacteria  Proteobacteria   Betaproteobacteria
# ...          ...       ...             ...                  ...
# 21190  NR_074339  Bacteria   Bacteroidetes           Cytophagia
# 21191  NR_074270  Bacteria        Chlorobi            Chlorobia
# 21192  NR_074244  Bacteria  Proteobacteria  Alphaproteobacteria
# 21193  NR_074234  Bacteria   Bacteroidetes          Bacteroidia
# 21194  NR_044194  Bacteria  Actinobacteria       Actinobacteria
#
#                    Order               Family              Genus     AAA  \
# 0        Mycobacteriales     Mycobacteriaceae      Mycobacterium  0.0104
# 1            Vibrionales         Vibrionaceae             Vibrio  0.0150
# 2        Mycobacteriales     Mycobacteriaceae      Mycobacterium  0.0101
# 3       Rhodospirillales     Acetobacteraceae        Acetobacter  0.0095
# 4        Burkholderiales       Comamonadaceae          Aquincola  0.0152
# ...                  ...                  ...                ...     ...
# 21190       Cytophagales        Cytophagaceae            Runella  0.0127
# 21191       Chlorobiales        Chlorobiaceae     Chloroherpeton  0.0162
# 21192        Rhizobiales  Methylobacteriaceae   Methylobacterium  0.0102
# 21193      Bacteroidales   Porphyromonadaceae      Porphyromonas  0.0136
# 21194  Pseudonocardiales   Pseudonocardiaceae  Saccharomonospora  0.0112
#
#           AAC     AAG  ...     TCT     TGA     TGC     TGG     TGT     TTA  \
# 0      0.0173  0.0208  ...  0.0069  0.0125  0.0194  0.0284  0.0160  0.0076
# 1      0.0176  0.0209  ...  0.0052  0.0202  0.0183  0.0248  0.0144  0.0104
# 2      0.0176  0.0196  ...  0.0054  0.0142  0.0176  0.0318  0.0149  0.0061
# 3      0.0154  0.0212  ...  0.0066  0.0220  0.0139  0.0308  0.0190  0.0088
# 4      0.0179  0.0214  ...  0.0062  0.0186  0.0200  0.0255  0.0117  0.0097
# ...       ...     ...  ...     ...     ...     ...     ...     ...     ...
# 21190  0.0161  0.0268  ...  0.0054  0.0174  0.0188  0.0255  0.0114  0.0121
# 21191  0.0162  0.0325  ...  0.0101  0.0217  0.0156  0.0250  0.0169  0.0129
# 21192  0.0163  0.0197  ...  0.0068  0.0183  0.0142  0.0299  0.0075  0.0102
# 21193  0.0197  0.0204  ...  0.0054  0.0244  0.0177  0.0143  0.0102  0.0136
# 21194  0.0154  0.0189  ...  0.0063  0.0168  0.0161  0.0307  0.0140  0.0070
#
#           TTC     TTG     TTT      CG
# 0      0.0083  0.0132  0.0062  0.5859
# 1      0.0078  0.0150  0.0065  0.5394
# 2      0.0095  0.0142  0.0054  0.5796
# 3      0.0088  0.0147  0.0073  0.5545
# 4      0.0055  0.0131  0.0062  0.5686
# ...       ...     ...     ...     ...
# 21190  0.0074  0.0141  0.0107  0.5224
# 21191  0.0068  0.0156  0.0061  0.5115
# 21192  0.0088  0.0129  0.0081  0.5752
# 21193  0.0102  0.0163  0.0075  0.5302
# 21194  0.0091  0.0112  0.0014  0.5955
#
# [21195 rows x 72 columns]

# %% [markdown]
# <h1>Количество элементов в каждой группе организмов</h1>

# %%
groups = df.groupby(groups_key)['ID'].count().to_frame(name = 'count').reset_index()
groups
# Out:
#                        Phylum                               Class  \
# 0            Abditibacteriota                      Abditibacteria
# 1                Acetothermia  Acetothermia_genera_incertae_sedis
# 2               Acidobacteria                   Acidobacteria_Gp1
# 3               Acidobacteria                   Acidobacteria_Gp1
# 4               Acidobacteria                   Acidobacteria_Gp1
# ..                        ...                                 ...
# 304            Woesearchaeota  Woesearchaeota_Incertae_Sedis_AR18
# 305            Woesearchaeota  Woesearchaeota_Incertae_Sedis_AR20
# 306  candidate_division_WPS-1         WPS-1_genera_incertae_sedis
# 307  candidate_division_WPS-2         WPS-2_genera_incertae_sedis
# 308    candidate_division_ZB3           ZB3_genera_incertae_sedis
#
#                  Order  count
# 0    Abditibacteriales      1
# 1                    _      1
# 2           Acidicapsa      6
# 3            Acidipila      2
# 4       Acidobacterium      3
# ..                 ...    ...
# 304                  _      1
# 305                  _      1
# 306                  _      2
# 307                  _      1
# 308                  _      1
#
# [309 rows x 4 columns]

# %% [markdown]
# # Сохраняем группы в таблицу Excel

# %%
xlsx_name = "groups.xlsx"
xlsx_path = join(DIRECTORY, xlsx_name)
with pd.ExcelWriter(xlsx_path) as writer:
    groups.to_excel(writer, 
                    sheet_name = "AllGroups", 
                    index=False)

# %% [markdown]
# # Статистические характеристики групп организмов

# %%
groups_describe = groups.describe()
groups_describe
# Out:
#              count
# count   309.000000
# mean     68.592233
# std     195.928564
# min       1.000000
# 25%       2.000000
# 50%       7.000000
# 75%      31.000000
# max    1782.000000

# %% [markdown]
# # По умолчанию мы обрезаем все группы, количество элементов в которых меньше среднего значения
# ## Если вы хотите выбрать другой параметр - измените значение переменной reduce_factor, расположенной ниже

# %%
reduce_factor = groups_describe.at['mean', 'count']
reduce_factor
# Out:
# 68.59223300970874

# %% [markdown]
# # Количество элементов в оставшихся группах микроорганизмов

# %%
reduced_groups = df.groupby(groups_key)['ID'].count()[lambda x: x > reduce_factor].to_frame(name = 'count').reset_index()
reduced_groups
# Out:
#                       Phylum                Class                Order  count
# 0             Actinobacteria       Actinobacteria      Actinomycetales     96
# 1             Actinobacteria       Actinobacteria    Bifidobacteriales    111
# 2             Actinobacteria       Actinobacteria        Micrococcales    940
# 3             Actinobacteria       Actinobacteria    Micromonosporales    297
# 4             Actinobacteria       Actinobacteria      Mycobacteriales    811
# 5             Actinobacteria       Actinobacteria  Propionibacteriales    286
# 6             Actinobacteria       Actinobacteria    Pseudonocardiales    401
# 7             Actinobacteria       Actinobacteria     Streptomycetales   1135
# 8             Actinobacteria       Actinobacteria  Streptosporangiales    414
# 9              Bacteroidetes          Bacteroidia        Bacteroidales    357
# 10             Bacteroidetes        Chitinophagia      Chitinophagales    164
# 11             Bacteroidetes           Cytophagia         Cytophagales    438
# 12             Bacteroidetes       Flavobacteriia     Flavobacteriales   1057
# 13             Bacteroidetes     Sphingobacteriia   Sphingobacteriales    254
# 14          Campilobacterota      Campylobacteria    Campylobacterales    181
# 15  CyanobacteriaChloroplast          Chloroplast          Chloroplast     86
# 16       Deinococcus-Thermus           Deinococci        Deinococcales     87
# 17             Euryarchaeota         Halobacteria      Halobacteriales    100
# 18             Euryarchaeota         Halobacteria        Haloferacales    109
# 19                Firmicutes              Bacilli           Bacillales   1782
# 20                Firmicutes              Bacilli      Lactobacillales    864
# 21                Firmicutes           Clostridia        Clostridiales    919
# 22                Firmicutes        Negativicutes      Selenomonadales     97
# 23              Fusobacteria        Fusobacteriia      Fusobacteriales     83
# 24            Proteobacteria  Alphaproteobacteria      Caulobacterales    129
# 25            Proteobacteria  Alphaproteobacteria          Rhizobiales    891
# 26            Proteobacteria  Alphaproteobacteria      Rhodobacterales    616
# 27            Proteobacteria  Alphaproteobacteria     Rhodospirillales    389
# 28            Proteobacteria  Alphaproteobacteria     Sphingomonadales    466
# 29            Proteobacteria   Betaproteobacteria      Burkholderiales    814
# 30            Proteobacteria   Betaproteobacteria         Neisseriales    129
# 31            Proteobacteria   Betaproteobacteria     Nitrosomonadales     71
# 32            Proteobacteria  Deltaproteobacteria    Desulfobacterales     81
# 33            Proteobacteria  Deltaproteobacteria   Desulfovibrionales    131
# 34            Proteobacteria  Deltaproteobacteria         Myxococcales     78
# 35            Proteobacteria  Gammaproteobacteria        Aeromonadales     83
# 36            Proteobacteria  Gammaproteobacteria      Alteromonadales    446
# 37            Proteobacteria  Gammaproteobacteria      Cellvibrionales    105
# 38            Proteobacteria  Gammaproteobacteria         Chromatiales    191
# 39            Proteobacteria  Gammaproteobacteria     Enterobacterales    550
# 40            Proteobacteria  Gammaproteobacteria        Legionellales     90
# 41            Proteobacteria  Gammaproteobacteria    Oceanospirillales    371
# 42            Proteobacteria  Gammaproteobacteria       Pasteurellales    146
# 43            Proteobacteria  Gammaproteobacteria      Pseudomonadales    492
# 44            Proteobacteria  Gammaproteobacteria        Thiotrichales     89
# 45            Proteobacteria  Gammaproteobacteria          Vibrionales    299
# 46            Proteobacteria  Gammaproteobacteria      Xanthomonadales    286
# 47              Spirochaetes         Spirochaetia       Spirochaetales    149
# 48               Tenericutes           Mollicutes     Mycoplasmoidales    139

# %% [markdown]
# # Добавляем новую таблицу в excel-файл

# %%
with pd.ExcelWriter(xlsx_path, mode='a') as writer:
    reduced_groups.to_excel(writer, 
                            sheet_name = 'ReducedGroups', 
                            index=False)

# %% [markdown]
# # Статистические характеристики оставшихся групп организмов

# %%
reduced_groups_describe = reduced_groups.describe()
rg_min_value = reduced_groups_describe.at['min', 'count']
reduced_groups_describe
# Out:
#              count
# count    49.000000
# mean    373.469388
# std     363.929543
# min      71.000000
# 25%     105.000000
# 50%     254.000000
# 75%     466.000000
# max    1782.000000

# %% [markdown]
# # Огранизмы, принадлежащие оставшимся группам

# %%
reduced_df = df.groupby(groups_key).filter(lambda group: len(group) > reduce_factor)
reduced_df
# Out:
#               ID    Domain          Phylum                Class  \
# 0       AJ000684  Bacteria  Actinobacteria       Actinobacteria
# 1       EF599163  Bacteria  Proteobacteria  Gammaproteobacteria
# 2       AY859683  Bacteria  Actinobacteria       Actinobacteria
# 3       AY883036  Bacteria  Proteobacteria  Alphaproteobacteria
# 4       DQ656489  Bacteria  Proteobacteria   Betaproteobacteria
# ...          ...       ...             ...                  ...
# 21189  NR_074344  Bacteria  Actinobacteria       Actinobacteria
# 21190  NR_074339  Bacteria   Bacteroidetes           Cytophagia
# 21192  NR_074244  Bacteria  Proteobacteria  Alphaproteobacteria
# 21193  NR_074234  Bacteria   Bacteroidetes          Bacteroidia
# 21194  NR_044194  Bacteria  Actinobacteria       Actinobacteria
#
#                    Order               Family              Genus     AAA  \
# 0        Mycobacteriales     Mycobacteriaceae      Mycobacterium  0.0104
# 1            Vibrionales         Vibrionaceae             Vibrio  0.0150
# 2        Mycobacteriales     Mycobacteriaceae      Mycobacterium  0.0101
# 3       Rhodospirillales     Acetobacteraceae        Acetobacter  0.0095
# 4        Burkholderiales       Comamonadaceae          Aquincola  0.0152
# ...                  ...                  ...                ...     ...
# 21189    Mycobacteriales   Corynebacteriaceae    Corynebacterium  0.0107
# 21190       Cytophagales        Cytophagaceae            Runella  0.0127
# 21192        Rhizobiales  Methylobacteriaceae   Methylobacterium  0.0102
# 21193      Bacteroidales   Porphyromonadaceae      Porphyromonas  0.0136
# 21194  Pseudonocardiales   Pseudonocardiaceae  Saccharomonospora  0.0112
#
#           AAC     AAG  ...     TCT     TGA     TGC     TGG     TGT     TTA  \
# 0      0.0173  0.0208  ...  0.0069  0.0125  0.0194  0.0284  0.0160  0.0076
# 1      0.0176  0.0209  ...  0.0052  0.0202  0.0183  0.0248  0.0144  0.0104
# 2      0.0176  0.0196  ...  0.0054  0.0142  0.0176  0.0318  0.0149  0.0061
# 3      0.0154  0.0212  ...  0.0066  0.0220  0.0139  0.0308  0.0190  0.0088
# 4      0.0179  0.0214  ...  0.0062  0.0186  0.0200  0.0255  0.0117  0.0097
# ...       ...     ...  ...     ...     ...     ...     ...     ...     ...
# 21189  0.0168  0.0195  ...  0.0060  0.0141  0.0174  0.0322  0.0154  0.0087
# 21190  0.0161  0.0268  ...  0.0054  0.0174  0.0188  0.0255  0.0114  0.0121
# 21192  0.0163  0.0197  ...  0.0068  0.0183  0.0142  0.0299  0.0075  0.0102
# 21193  0.0197  0.0204  ...  0.0054  0.0244  0.0177  0.0143  0.0102  0.0136
# 21194  0.0154  0.0189  ...  0.0063  0.0168  0.0161  0.0307  0.0140  0.0070
#
#           TTC     TTG     TTT      CG
# 0      0.0083  0.0132  0.0062  0.5859
# 1      0.0078  0.0150  0.0065  0.5394
# 2      0.0095  0.0142  0.0054  0.5796
# 3      0.0088  0.0147  0.0073  0.5545
# 4      0.0055  0.0131  0.0062  0.5686
# ...       ...     ...     ...     ...
# 21189  0.0107  0.0154  0.0080  0.5680
# 21190  0.0074  0.0141  0.0107  0.5224
# 21192  0.0088  0.0129  0.0081  0.5752
# 21193  0.0102  0.0163  0.0075  0.5302
# 21194  0.0091  0.0112  0.0014  0.5955
#
# [18300 rows x 72 columns]

# %%
reduced_df.set_index('ID')
# Out:
#              Domain          Phylum                Class              Order  \
# ID
# AJ000684   Bacteria  Actinobacteria       Actinobacteria    Mycobacteriales
# EF599163   Bacteria  Proteobacteria  Gammaproteobacteria        Vibrionales
# AY859683   Bacteria  Actinobacteria       Actinobacteria    Mycobacteriales
# AY883036   Bacteria  Proteobacteria  Alphaproteobacteria   Rhodospirillales
# DQ656489   Bacteria  Proteobacteria   Betaproteobacteria    Burkholderiales
# ...             ...             ...                  ...                ...
# NR_074344  Bacteria  Actinobacteria       Actinobacteria    Mycobacteriales
# NR_074339  Bacteria   Bacteroidetes           Cytophagia       Cytophagales
# NR_074244  Bacteria  Proteobacteria  Alphaproteobacteria        Rhizobiales
# NR_074234  Bacteria   Bacteroidetes          Bacteroidia      Bacteroidales
# NR_044194  Bacteria  Actinobacteria       Actinobacteria  Pseudonocardiales
#
#                         Family              Genus     AAA     AAC     AAG  \
# ID
# AJ000684      Mycobacteriaceae      Mycobacterium  0.0104  0.0173  0.0208
# EF599163          Vibrionaceae             Vibrio  0.0150  0.0176  0.0209
# AY859683      Mycobacteriaceae      Mycobacterium  0.0101  0.0176  0.0196
# AY883036      Acetobacteraceae        Acetobacter  0.0095  0.0154  0.0212
# DQ656489        Comamonadaceae          Aquincola  0.0152  0.0179  0.0214
# ...                        ...                ...     ...     ...     ...
# NR_074344   Corynebacteriaceae    Corynebacterium  0.0107  0.0168  0.0195
# NR_074339        Cytophagaceae            Runella  0.0127  0.0161  0.0268
# NR_074244  Methylobacteriaceae   Methylobacterium  0.0102  0.0163  0.0197
# NR_074234   Porphyromonadaceae      Porphyromonas  0.0136  0.0197  0.0204
# NR_044194   Pseudonocardiaceae  Saccharomonospora  0.0112  0.0154  0.0189
#
#               AAT  ...     TCT     TGA     TGC     TGG     TGT     TTA  \
# ID                 ...
# AJ000684   0.0111  ...  0.0069  0.0125  0.0194  0.0284  0.0160  0.0076
# EF599163   0.0189  ...  0.0052  0.0202  0.0183  0.0248  0.0144  0.0104
# AY859683   0.0108  ...  0.0054  0.0142  0.0176  0.0318  0.0149  0.0061
# AY883036   0.0117  ...  0.0066  0.0220  0.0139  0.0308  0.0190  0.0088
# DQ656489   0.0152  ...  0.0062  0.0186  0.0200  0.0255  0.0117  0.0097
# ...           ...  ...     ...     ...     ...     ...     ...     ...
# NR_074344  0.0114  ...  0.0060  0.0141  0.0174  0.0322  0.0154  0.0087
# NR_074339  0.0161  ...  0.0054  0.0174  0.0188  0.0255  0.0114  0.0121
# NR_074244  0.0122  ...  0.0068  0.0183  0.0142  0.0299  0.0075  0.0102
# NR_074234  0.0129  ...  0.0054  0.0244  0.0177  0.0143  0.0102  0.0136
# NR_044194  0.0098  ...  0.0063  0.0168  0.0161  0.0307  0.0140  0.0070
#
#               TTC     TTG     TTT      CG
# ID
# AJ000684   0.0083  0.0132  0.0062  0.5859
# EF599163   0.0078  0.0150  0.0065  0.5394
# AY859683   0.0095  0.0142  0.0054  0.5796
# AY883036   0.0088  0.0147  0.0073  0.5545
# DQ656489   0.0055  0.0131  0.0062  0.5686
# ...           ...     ...     ...     ...
# NR_074344  0.0107  0.0154  0.0080  0.5680
# NR_074339  0.0074  0.0141  0.0107  0.5224
# NR_074244  0.0088  0.0129  0.0081  0.5752
# NR_074234  0.0102  0.0163  0.0075  0.5302
# NR_044194  0.0091  0.0112  0.0014  0.5955
#
# [18300 rows x 71 columns]

# %% [markdown]
# # Производим стратифицированную выборку

# %%
stratified_sampling = reduced_df.groupby(groups_key).apply(lambda group: group.sample(int(rg_min_value))).set_index('ID')
stratified_sampling
# Out:
#              Domain          Phylum           Class             Order  \
# ID
# AJ427451   Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# X80413     Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# EF558367   Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# NR_113326  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# JQ780830   Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# ...             ...             ...             ...               ...
# AB680682   Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# AF412989   Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# AF125592   Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# AY714305   Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# AF304323   Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
#
#                          Family           Genus     AAA     AAC     AAG  \
# ID
# AJ427451       Actinomycetaceae        Schaalia  0.0094  0.0181  0.0174
# X80413         Actinomycetaceae        Schaalia  0.0106  0.0176  0.0176
# EF558367       Actinomycetaceae     Actinomyces  0.0081  0.0149  0.0162
# NR_113326      Actinomycetaceae     Actinomyces  0.0079  0.0171  0.0184
# JQ780830       Actinomycetaceae     Varibaculum  0.0106  0.0158  0.0196
# ...                         ...             ...     ...     ...     ...
# AB680682   Metamycoplasmataceae  Metamycoplasma  0.0173  0.0160  0.0243
# AF412989   Metamycoplasmataceae  Mycoplasmopsis  0.0248  0.0227  0.0227
# AF125592   Metamycoplasmataceae  Metamycoplasma  0.0221  0.0152  0.0255
# AY714305   Metamycoplasmataceae  Mycoplasmopsis  0.0223  0.0216  0.0216
# AF304323   Metamycoplasmataceae  Metamycoplasma  0.0192  0.0171  0.0247
#
#               AAT  ...     TCT     TGA     TGC     TGG     TGT     TTA  \
# ID                 ...
# AJ427451   0.0101  ...  0.0080  0.0168  0.0188  0.0389  0.0121  0.0087
# X80413     0.0099  ...  0.0085  0.0183  0.0183  0.0380  0.0127  0.0085
# EF558367   0.0101  ...  0.0088  0.0183  0.0176  0.0412  0.0142  0.0088
# NR_113326  0.0092  ...  0.0105  0.0184  0.0171  0.0375  0.0145  0.0072
# JQ780830   0.0090  ...  0.0128  0.0158  0.0219  0.0392  0.0203  0.0121
# ...           ...  ...     ...     ...     ...     ...     ...     ...
# AB680682   0.0215  ...  0.0104  0.0250  0.0153  0.0257  0.0125  0.0173
# AF412989   0.0207  ...  0.0103  0.0200  0.0131  0.0227  0.0131  0.0207
# AF125592   0.0207  ...  0.0103  0.0241  0.0138  0.0262  0.0124  0.0172
# AY714305   0.0187  ...  0.0079  0.0223  0.0151  0.0209  0.0115  0.0223
# AF304323   0.0185  ...  0.0096  0.0212  0.0130  0.0274  0.0123  0.0164
#
#               TTC     TTG     TTT      CG
# ID
# AJ427451   0.0087  0.0248  0.0094  0.5733
# X80413     0.0070  0.0197  0.0070  0.5963
# EF558367   0.0095  0.0223  0.0156  0.5915
# NR_113326  0.0086  0.0184  0.0105  0.5913
# JQ780830   0.0090  0.0271  0.0181  0.5576
# ...           ...     ...     ...     ...
# AB680682   0.0090  0.0146  0.0083  0.4851
# AF412989   0.0083  0.0145  0.0076  0.4746
# AF125592   0.0083  0.0131  0.0069  0.4880
# AY714305   0.0072  0.0166  0.0094  0.4831
# AF304323   0.0082  0.0137  0.0089  0.4952
#
# [3479 rows x 71 columns]

# %% [markdown]
# # Сохраняем данные в формате csv

# %%
reset_sample = stratified_sampling.reset_index()
reset_sample
# Out:
#              ID    Domain          Phylum           Class             Order  \
# 0      AJ427451  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# 1        X80413  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# 2      EF558367  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# 3     NR_113326  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# 4      JQ780830  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# ...         ...       ...             ...             ...               ...
# 3474   AB680682  Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# 3475   AF412989  Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# 3476   AF125592  Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# 3477   AY714305  Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# 3478   AF304323  Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
#
#                     Family           Genus     AAA     AAC     AAG  ...  \
# 0         Actinomycetaceae        Schaalia  0.0094  0.0181  0.0174  ...
# 1         Actinomycetaceae        Schaalia  0.0106  0.0176  0.0176  ...
# 2         Actinomycetaceae     Actinomyces  0.0081  0.0149  0.0162  ...
# 3         Actinomycetaceae     Actinomyces  0.0079  0.0171  0.0184  ...
# 4         Actinomycetaceae     Varibaculum  0.0106  0.0158  0.0196  ...
# ...                    ...             ...     ...     ...     ...  ...
# 3474  Metamycoplasmataceae  Metamycoplasma  0.0173  0.0160  0.0243  ...
# 3475  Metamycoplasmataceae  Mycoplasmopsis  0.0248  0.0227  0.0227  ...
# 3476  Metamycoplasmataceae  Metamycoplasma  0.0221  0.0152  0.0255  ...
# 3477  Metamycoplasmataceae  Mycoplasmopsis  0.0223  0.0216  0.0216  ...
# 3478  Metamycoplasmataceae  Metamycoplasma  0.0192  0.0171  0.0247  ...
#
#          TCT     TGA     TGC     TGG     TGT     TTA     TTC     TTG     TTT  \
# 0     0.0080  0.0168  0.0188  0.0389  0.0121  0.0087  0.0087  0.0248  0.0094
# 1     0.0085  0.0183  0.0183  0.0380  0.0127  0.0085  0.0070  0.0197  0.0070
# 2     0.0088  0.0183  0.0176  0.0412  0.0142  0.0088  0.0095  0.0223  0.0156
# 3     0.0105  0.0184  0.0171  0.0375  0.0145  0.0072  0.0086  0.0184  0.0105
# 4     0.0128  0.0158  0.0219  0.0392  0.0203  0.0121  0.0090  0.0271  0.0181
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 3474  0.0104  0.0250  0.0153  0.0257  0.0125  0.0173  0.0090  0.0146  0.0083
# 3475  0.0103  0.0200  0.0131  0.0227  0.0131  0.0207  0.0083  0.0145  0.0076
# 3476  0.0103  0.0241  0.0138  0.0262  0.0124  0.0172  0.0083  0.0131  0.0069
# 3477  0.0079  0.0223  0.0151  0.0209  0.0115  0.0223  0.0072  0.0166  0.0094
# 3478  0.0096  0.0212  0.0130  0.0274  0.0123  0.0164  0.0082  0.0137  0.0089
#
#           CG
# 0     0.5733
# 1     0.5963
# 2     0.5915
# 3     0.5913
# 4     0.5576
# ...      ...
# 3474  0.4851
# 3475  0.4746
# 3476  0.4880
# 3477  0.4831
# 3478  0.4952
#
# [3479 rows x 72 columns]

# %%
reset_sample.to_csv('sampling_data.csv',
                           sep=';',
                           encoding='utf-8',
                           index=False)

# %% [markdown]
# # Сохраняем в формате dat
# ## Выбор CR/LF обсуловлен программой для дальнейшей обработки этих данных

# %%
reduced_dat = "reduced_" + dataset_name
with open(reduced_dat, 'w', encoding='utf-8', newline='\r\n') as f:
    f.write(f"{columns_count}\t{rows_count}\n")
    for key in column_to_type:
        f.write(f"{key}\t{column_to_type[key]}\n")
        
reset_sample.to_csv(reduced_dat, sep='\t', mode='a', header=False, index=False, lineterminator='\r\n')

# %% [markdown]
# # Находим наименьшее из среднеквадратических отклонений и триплет, соответствующий этому значению

# %% [markdown]
# ## Вычисляем отклонения

# %%
std_triplet = reset_sample.std(numeric_only=True)
std_triplet
# Out:
# AAA    0.003135
# AAC    0.002053
# AAG    0.002833
# AAT    0.003257
# ACA    0.002062
#          ...
# TTA    0.003394
# TTC    0.002036
# TTG    0.002720
# TTT    0.002846
# CG     0.030294
# Length: 65, dtype: float64

# %% [markdown]
# ## Находим триплет с наименьшим среднеквадратическим отклонением

# %%
min_triplet_index = std_triplet.idxmin()
min_triplet_index
# Out:
# 'TCA'

# %% [markdown]
# ## Среднеквадратическое отклонение этого триплета

# %%
std_triplet[min_triplet_index]
# Out:
# 0.0017425800348062973
