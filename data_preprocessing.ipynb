# %%
import pandas as pd
import numpy as np
from os import getcwd
from os.path import join

# %%
DIRECTORY = getcwd()
DIRECTORY
# Out:
# 'C:\\Users\\conf\\Desktop\\agnia'

# %% [markdown]
# # Путь до директории, в которой лежит ноутбук, вычисляется самостоятельно
# # Необходимо указать лишь имя файла

# %%
dataset_name = "rdp_16s_v18.fa.dat"
dataset_path = join(DIRECTORY, dataset_name)

# %%
headers = []
with open(dataset_path) as datFile:
    datFile.readline()
    for _ in range(72):
        line = datFile.readline().split('\t')
        headers.append(line[0])

# %% [markdown]
# # 'Domain' - Домен
# # 'Phylum' - Тип
# # 'Class' - Класс
# # 'Order' - Порядок
# # 'Family' - Семейство
# # 'Genus' - Род

# %%
groups_key = ['Phylum', 'Class', 'Order']
headers[1:7] = ["Domain"] + groups_key + ["Family", "Genus"]

# %%
df = pd.read_csv(dataset_path, delimiter="\t", names=headers, skiprows=74)

# %% [markdown]
# # Исходный датасет

# %%
df
# Out:
#               ID    Domain          Phylum                Class  \
# 0       EF599163  Bacteria  Proteobacteria  Gammaproteobacteria
# 1       AY859683  Bacteria  Actinobacteria       Actinobacteria
# 2       AY883036  Bacteria  Proteobacteria  Alphaproteobacteria
# 3       DQ656489  Bacteria  Proteobacteria   Betaproteobacteria
# 4         D85479  Bacteria  Actinobacteria       Actinobacteria
# ...          ...       ...             ...                  ...
# 21189  NR_074339  Bacteria   Bacteroidetes           Cytophagia
# 21190  NR_074270  Bacteria        Chlorobi            Chlorobia
# 21191  NR_074244  Bacteria  Proteobacteria  Alphaproteobacteria
# 21192  NR_074234  Bacteria   Bacteroidetes          Bacteroidia
# 21193  NR_044194  Bacteria  Actinobacteria       Actinobacteria
#
#                    Order               Family              Genus     AAA  \
# 0            Vibrionales         Vibrionaceae             Vibrio  0.0150
# 1        Mycobacteriales     Mycobacteriaceae      Mycobacterium  0.0101
# 2       Rhodospirillales     Acetobacteraceae        Acetobacter  0.0095
# 3        Burkholderiales       Comamonadaceae          Aquincola  0.0152
# 4      Micromonosporales   Micromonosporaceae      Couchioplanes  0.0136
# ...                  ...                  ...                ...     ...
# 21189       Cytophagales        Cytophagaceae            Runella  0.0127
# 21190       Chlorobiales        Chlorobiaceae     Chloroherpeton  0.0162
# 21191        Rhizobiales  Methylobacteriaceae   Methylobacterium  0.0102
# 21192      Bacteroidales   Porphyromonadaceae      Porphyromonas  0.0136
# 21193  Pseudonocardiales   Pseudonocardiaceae  Saccharomonospora  0.0112
#
#           AAC     AAG  ...     TCT     TGA     TGC     TGG     TGT     TTA  \
# 0      0.0176  0.0209  ...  0.0052  0.0202  0.0183  0.0248  0.0144  0.0104
# 1      0.0176  0.0196  ...  0.0054  0.0142  0.0176  0.0318  0.0149  0.0061
# 2      0.0154  0.0212  ...  0.0066  0.0220  0.0139  0.0308  0.0190  0.0088
# 3      0.0179  0.0214  ...  0.0062  0.0186  0.0200  0.0255  0.0117  0.0097
# 4      0.0170  0.0218  ...  0.0068  0.0143  0.0150  0.0252  0.0116  0.0061
# ...       ...     ...  ...     ...     ...     ...     ...     ...     ...
# 21189  0.0161  0.0268  ...  0.0054  0.0174  0.0188  0.0255  0.0114  0.0121
# 21190  0.0162  0.0325  ...  0.0101  0.0217  0.0156  0.0250  0.0169  0.0129
# 21191  0.0163  0.0197  ...  0.0068  0.0183  0.0142  0.0299  0.0075  0.0102
# 21192  0.0197  0.0204  ...  0.0054  0.0244  0.0177  0.0143  0.0102  0.0136
# 21193  0.0154  0.0189  ...  0.0063  0.0168  0.0161  0.0307  0.0140  0.0070
#
#           TTC     TTG     TTT      CG
# 0      0.0078  0.0150  0.0065  0.5394
# 1      0.0095  0.0142  0.0054  0.5796
# 2      0.0088  0.0147  0.0073  0.5545
# 3      0.0055  0.0131  0.0062  0.5686
# 4      0.0102  0.0116  0.0054  0.6014
# ...       ...     ...     ...     ...
# 21189  0.0074  0.0141  0.0107  0.5224
# 21190  0.0068  0.0156  0.0061  0.5115
# 21191  0.0088  0.0129  0.0081  0.5752
# 21192  0.0102  0.0163  0.0075  0.5302
# 21193  0.0091  0.0112  0.0014  0.5955
#
# [21194 rows x 72 columns]

# %% [markdown]
# <h1>Количество элементов в каждой группе организмов</h1>

# %%
groups = df.groupby(groups_key)['ID'].count().to_frame(name = 'count').reset_index()
groups
# Out:
#                        Phylum                               Class  \
# 0            Abditibacteriota                      Abditibacteria
# 1                Acetothermia  Acetothermia_genera_incertae_sedis
# 2               Acidobacteria                   Acidobacteria_Gp1
# 3               Acidobacteria                   Acidobacteria_Gp1
# 4               Acidobacteria                   Acidobacteria_Gp1
# ..                        ...                                 ...
# 304            Woesearchaeota  Woesearchaeota_Incertae_Sedis_AR18
# 305            Woesearchaeota  Woesearchaeota_Incertae_Sedis_AR20
# 306  candidate_division_WPS-1         WPS-1_genera_incertae_sedis
# 307  candidate_division_WPS-2         WPS-2_genera_incertae_sedis
# 308    candidate_division_ZB3           ZB3_genera_incertae_sedis
#
#                  Order  count
# 0    Abditibacteriales      1
# 1                    _      1
# 2           Acidicapsa      6
# 3            Acidipila      2
# 4       Acidobacterium      3
# ..                 ...    ...
# 304                  _      1
# 305                  _      1
# 306                  _      2
# 307                  _      1
# 308                  _      1
#
# [309 rows x 4 columns]

# %% [markdown]
# # Сохраняем группы в таблицу Excel

# %%
xlsx_name = "groups.xlsx"
xlsx_path = join(DIRECTORY, xlsx_name)
with pd.ExcelWriter(xlsx_path) as writer:
    groups.to_excel(writer, 
                    sheet_name = "AllGroups", 
                    index=False)

# %% [markdown]
# # Статистические характеристики групп организмов

# %%
groups_describe = groups.describe()
groups_describe
# Out:
#              count
# count   309.000000
# mean     68.588997
# std     195.916269
# min       1.000000
# 25%       2.000000
# 50%       7.000000
# 75%      31.000000
# max    1782.000000

# %% [markdown]
# # По умолчанию мы обрезаем все группы, количество элементов в которых меньше среднего значения
# ## Если вы хотите выбрать другой параметр - измените значение переменной reduce_factor, расположенной ниже

# %%
reduce_factor = groups_describe.at['mean', 'count']
reduce_factor
# Out:
# 68.58899676375404

# %% [markdown]
# # Количество элементов в оставшихся группах микроорганизмов

# %%
reduced_groups = df.groupby(groups_key)['ID'].count()[lambda x: x > reduce_factor].to_frame(name = 'count').reset_index()
reduced_groups
# Out:
#                       Phylum                Class                Order  count
# 0             Actinobacteria       Actinobacteria      Actinomycetales     96
# 1             Actinobacteria       Actinobacteria    Bifidobacteriales    111
# 2             Actinobacteria       Actinobacteria        Micrococcales    940
# 3             Actinobacteria       Actinobacteria    Micromonosporales    297
# 4             Actinobacteria       Actinobacteria      Mycobacteriales    810
# 5             Actinobacteria       Actinobacteria  Propionibacteriales    286
# 6             Actinobacteria       Actinobacteria    Pseudonocardiales    401
# 7             Actinobacteria       Actinobacteria     Streptomycetales   1135
# 8             Actinobacteria       Actinobacteria  Streptosporangiales    414
# 9              Bacteroidetes          Bacteroidia        Bacteroidales    357
# 10             Bacteroidetes        Chitinophagia      Chitinophagales    164
# 11             Bacteroidetes           Cytophagia         Cytophagales    438
# 12             Bacteroidetes       Flavobacteriia     Flavobacteriales   1057
# 13             Bacteroidetes     Sphingobacteriia   Sphingobacteriales    254
# 14          Campilobacterota      Campylobacteria    Campylobacterales    181
# 15  CyanobacteriaChloroplast          Chloroplast          Chloroplast     86
# 16       Deinococcus-Thermus           Deinococci        Deinococcales     87
# 17             Euryarchaeota         Halobacteria      Halobacteriales    100
# 18             Euryarchaeota         Halobacteria        Haloferacales    109
# 19                Firmicutes              Bacilli           Bacillales   1782
# 20                Firmicutes              Bacilli      Lactobacillales    864
# 21                Firmicutes           Clostridia        Clostridiales    919
# 22                Firmicutes        Negativicutes      Selenomonadales     97
# 23              Fusobacteria        Fusobacteriia      Fusobacteriales     83
# 24            Proteobacteria  Alphaproteobacteria      Caulobacterales    129
# 25            Proteobacteria  Alphaproteobacteria          Rhizobiales    891
# 26            Proteobacteria  Alphaproteobacteria      Rhodobacterales    616
# 27            Proteobacteria  Alphaproteobacteria     Rhodospirillales    389
# 28            Proteobacteria  Alphaproteobacteria     Sphingomonadales    466
# 29            Proteobacteria   Betaproteobacteria      Burkholderiales    814
# 30            Proteobacteria   Betaproteobacteria         Neisseriales    129
# 31            Proteobacteria   Betaproteobacteria     Nitrosomonadales     71
# 32            Proteobacteria  Deltaproteobacteria    Desulfobacterales     81
# 33            Proteobacteria  Deltaproteobacteria   Desulfovibrionales    131
# 34            Proteobacteria  Deltaproteobacteria         Myxococcales     78
# 35            Proteobacteria  Gammaproteobacteria        Aeromonadales     83
# 36            Proteobacteria  Gammaproteobacteria      Alteromonadales    446
# 37            Proteobacteria  Gammaproteobacteria      Cellvibrionales    105
# 38            Proteobacteria  Gammaproteobacteria         Chromatiales    191
# 39            Proteobacteria  Gammaproteobacteria     Enterobacterales    550
# 40            Proteobacteria  Gammaproteobacteria        Legionellales     90
# 41            Proteobacteria  Gammaproteobacteria    Oceanospirillales    371
# 42            Proteobacteria  Gammaproteobacteria       Pasteurellales    146
# 43            Proteobacteria  Gammaproteobacteria      Pseudomonadales    492
# 44            Proteobacteria  Gammaproteobacteria        Thiotrichales     89
# 45            Proteobacteria  Gammaproteobacteria          Vibrionales    299
# 46            Proteobacteria  Gammaproteobacteria      Xanthomonadales    286
# 47              Spirochaetes         Spirochaetia       Spirochaetales    149
# 48               Tenericutes           Mollicutes     Mycoplasmoidales    139

# %% [markdown]
# # Добавляем новую таблицу в excel-файл

# %%
with pd.ExcelWriter(xlsx_path, mode='a') as writer:
    reduced_groups.to_excel(writer, 
                            sheet_name = 'ReducedGroups', 
                            index=False)

# %% [markdown]
# # Статистические характеристики оставшихся групп организмов

# %%
reduced_groups_describe = reduced_groups.describe()
rg_min_value = reduced_groups_describe.at['min', 'count']
reduced_groups_describe
# Out:
#              count
# count    49.000000
# mean    373.448980
# std     363.904524
# min      71.000000
# 25%     105.000000
# 50%     254.000000
# 75%     466.000000
# max    1782.000000

# %% [markdown]
# # Огранизмы, принадлежащие оставшимся группам

# %%
reduced_df = df.groupby(groups_key).filter(lambda group: len(group) > reduce_factor)
reduced_df
# Out:
#               ID    Domain          Phylum                Class  \
# 0       EF599163  Bacteria  Proteobacteria  Gammaproteobacteria
# 1       AY859683  Bacteria  Actinobacteria       Actinobacteria
# 2       AY883036  Bacteria  Proteobacteria  Alphaproteobacteria
# 3       DQ656489  Bacteria  Proteobacteria   Betaproteobacteria
# 4         D85479  Bacteria  Actinobacteria       Actinobacteria
# ...          ...       ...             ...                  ...
# 21188  NR_074344  Bacteria  Actinobacteria       Actinobacteria
# 21189  NR_074339  Bacteria   Bacteroidetes           Cytophagia
# 21191  NR_074244  Bacteria  Proteobacteria  Alphaproteobacteria
# 21192  NR_074234  Bacteria   Bacteroidetes          Bacteroidia
# 21193  NR_044194  Bacteria  Actinobacteria       Actinobacteria
#
#                    Order               Family              Genus     AAA  \
# 0            Vibrionales         Vibrionaceae             Vibrio  0.0150
# 1        Mycobacteriales     Mycobacteriaceae      Mycobacterium  0.0101
# 2       Rhodospirillales     Acetobacteraceae        Acetobacter  0.0095
# 3        Burkholderiales       Comamonadaceae          Aquincola  0.0152
# 4      Micromonosporales   Micromonosporaceae      Couchioplanes  0.0136
# ...                  ...                  ...                ...     ...
# 21188    Mycobacteriales   Corynebacteriaceae    Corynebacterium  0.0107
# 21189       Cytophagales        Cytophagaceae            Runella  0.0127
# 21191        Rhizobiales  Methylobacteriaceae   Methylobacterium  0.0102
# 21192      Bacteroidales   Porphyromonadaceae      Porphyromonas  0.0136
# 21193  Pseudonocardiales   Pseudonocardiaceae  Saccharomonospora  0.0112
#
#           AAC     AAG  ...     TCT     TGA     TGC     TGG     TGT     TTA  \
# 0      0.0176  0.0209  ...  0.0052  0.0202  0.0183  0.0248  0.0144  0.0104
# 1      0.0176  0.0196  ...  0.0054  0.0142  0.0176  0.0318  0.0149  0.0061
# 2      0.0154  0.0212  ...  0.0066  0.0220  0.0139  0.0308  0.0190  0.0088
# 3      0.0179  0.0214  ...  0.0062  0.0186  0.0200  0.0255  0.0117  0.0097
# 4      0.0170  0.0218  ...  0.0068  0.0143  0.0150  0.0252  0.0116  0.0061
# ...       ...     ...  ...     ...     ...     ...     ...     ...     ...
# 21188  0.0168  0.0195  ...  0.0060  0.0141  0.0174  0.0322  0.0154  0.0087
# 21189  0.0161  0.0268  ...  0.0054  0.0174  0.0188  0.0255  0.0114  0.0121
# 21191  0.0163  0.0197  ...  0.0068  0.0183  0.0142  0.0299  0.0075  0.0102
# 21192  0.0197  0.0204  ...  0.0054  0.0244  0.0177  0.0143  0.0102  0.0136
# 21193  0.0154  0.0189  ...  0.0063  0.0168  0.0161  0.0307  0.0140  0.0070
#
#           TTC     TTG     TTT      CG
# 0      0.0078  0.0150  0.0065  0.5394
# 1      0.0095  0.0142  0.0054  0.5796
# 2      0.0088  0.0147  0.0073  0.5545
# 3      0.0055  0.0131  0.0062  0.5686
# 4      0.0102  0.0116  0.0054  0.6014
# ...       ...     ...     ...     ...
# 21188  0.0107  0.0154  0.0080  0.5680
# 21189  0.0074  0.0141  0.0107  0.5224
# 21191  0.0088  0.0129  0.0081  0.5752
# 21192  0.0102  0.0163  0.0075  0.5302
# 21193  0.0091  0.0112  0.0014  0.5955
#
# [18299 rows x 72 columns]

# %%
reduced_df.set_index('ID')
# Out:
#              Domain          Phylum                Class              Order  \
# ID
# EF599163   Bacteria  Proteobacteria  Gammaproteobacteria        Vibrionales
# AY859683   Bacteria  Actinobacteria       Actinobacteria    Mycobacteriales
# AY883036   Bacteria  Proteobacteria  Alphaproteobacteria   Rhodospirillales
# DQ656489   Bacteria  Proteobacteria   Betaproteobacteria    Burkholderiales
# D85479     Bacteria  Actinobacteria       Actinobacteria  Micromonosporales
# ...             ...             ...                  ...                ...
# NR_074344  Bacteria  Actinobacteria       Actinobacteria    Mycobacteriales
# NR_074339  Bacteria   Bacteroidetes           Cytophagia       Cytophagales
# NR_074244  Bacteria  Proteobacteria  Alphaproteobacteria        Rhizobiales
# NR_074234  Bacteria   Bacteroidetes          Bacteroidia      Bacteroidales
# NR_044194  Bacteria  Actinobacteria       Actinobacteria  Pseudonocardiales
#
#                         Family              Genus     AAA     AAC     AAG  \
# ID
# EF599163          Vibrionaceae             Vibrio  0.0150  0.0176  0.0209
# AY859683      Mycobacteriaceae      Mycobacterium  0.0101  0.0176  0.0196
# AY883036      Acetobacteraceae        Acetobacter  0.0095  0.0154  0.0212
# DQ656489        Comamonadaceae          Aquincola  0.0152  0.0179  0.0214
# D85479      Micromonosporaceae      Couchioplanes  0.0136  0.0170  0.0218
# ...                        ...                ...     ...     ...     ...
# NR_074344   Corynebacteriaceae    Corynebacterium  0.0107  0.0168  0.0195
# NR_074339        Cytophagaceae            Runella  0.0127  0.0161  0.0268
# NR_074244  Methylobacteriaceae   Methylobacterium  0.0102  0.0163  0.0197
# NR_074234   Porphyromonadaceae      Porphyromonas  0.0136  0.0197  0.0204
# NR_044194   Pseudonocardiaceae  Saccharomonospora  0.0112  0.0154  0.0189
#
#               AAT  ...     TCT     TGA     TGC     TGG     TGT     TTA  \
# ID                 ...
# EF599163   0.0189  ...  0.0052  0.0202  0.0183  0.0248  0.0144  0.0104
# AY859683   0.0108  ...  0.0054  0.0142  0.0176  0.0318  0.0149  0.0061
# AY883036   0.0117  ...  0.0066  0.0220  0.0139  0.0308  0.0190  0.0088
# DQ656489   0.0152  ...  0.0062  0.0186  0.0200  0.0255  0.0117  0.0097
# D85479     0.0075  ...  0.0068  0.0143  0.0150  0.0252  0.0116  0.0061
# ...           ...  ...     ...     ...     ...     ...     ...     ...
# NR_074344  0.0114  ...  0.0060  0.0141  0.0174  0.0322  0.0154  0.0087
# NR_074339  0.0161  ...  0.0054  0.0174  0.0188  0.0255  0.0114  0.0121
# NR_074244  0.0122  ...  0.0068  0.0183  0.0142  0.0299  0.0075  0.0102
# NR_074234  0.0129  ...  0.0054  0.0244  0.0177  0.0143  0.0102  0.0136
# NR_044194  0.0098  ...  0.0063  0.0168  0.0161  0.0307  0.0140  0.0070
#
#               TTC     TTG     TTT      CG
# ID
# EF599163   0.0078  0.0150  0.0065  0.5394
# AY859683   0.0095  0.0142  0.0054  0.5796
# AY883036   0.0088  0.0147  0.0073  0.5545
# DQ656489   0.0055  0.0131  0.0062  0.5686
# D85479     0.0102  0.0116  0.0054  0.6014
# ...           ...     ...     ...     ...
# NR_074344  0.0107  0.0154  0.0080  0.5680
# NR_074339  0.0074  0.0141  0.0107  0.5224
# NR_074244  0.0088  0.0129  0.0081  0.5752
# NR_074234  0.0102  0.0163  0.0075  0.5302
# NR_044194  0.0091  0.0112  0.0014  0.5955
#
# [18299 rows x 71 columns]

# %% [markdown]
# # Производим стратифицированную выборку

# %%
stratified_sampling = reduced_df.groupby(groups_key).apply(lambda group: group.sample(int(rg_min_value))).set_index('ID')
stratified_sampling
# Out:
#              Domain          Phylum           Class             Order  \
# ID
# AM084229   Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# KC196072   Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# FJ617539   Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# AJ318408   Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# NR_119012  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# ...             ...             ...             ...               ...
# L24106     Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# AJ419905   Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# U58504     Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# AF125591   Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# AF412977   Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
#
#                          Family           Genus     AAA     AAC     AAG  \
# ID
# AM084229       Actinomycetaceae          Winkia  0.0100  0.0161  0.0187
# KC196072       Actinomycetaceae     Actinomyces  0.0089  0.0172  0.0185
# FJ617539       Actinomycetaceae         Gleimia  0.0100  0.0140  0.0187
# AJ318408       Actinomycetaceae      Mobiluncus  0.0108  0.0168  0.0182
# NR_119012      Actinomycetaceae          Winkia  0.0094  0.0162  0.0188
# ...                         ...             ...     ...     ...     ...
# L24106     Metamycoplasmataceae  Mycoplasmopsis  0.0279  0.0209  0.0251
# AJ419905   Metamycoplasmataceae  Mycoplasmopsis  0.0246  0.0181  0.0224
# U58504     Metamycoplasmataceae  Mycoplasmopsis  0.0220  0.0207  0.0220
# AF125591   Metamycoplasmataceae  Metamycoplasma  0.0192  0.0178  0.0253
# AF412977   Metamycoplasmataceae  Mycoplasmopsis  0.0208  0.0187  0.0249
#
#               AAT  ...     TCT     TGA     TGC     TGG     TGT     TTA  \
# ID                 ...
# AM084229   0.0080  ...  0.0087  0.0147  0.0187  0.0368  0.0161  0.0120
# KC196072   0.0096  ...  0.0096  0.0185  0.0158  0.0357  0.0110  0.0082
# FJ617539   0.0113  ...  0.0140  0.0173  0.0187  0.0393  0.0173  0.0113
# AJ318408   0.0087  ...  0.0094  0.0155  0.0175  0.0370  0.0155  0.0101
# NR_119012  0.0081  ...  0.0087  0.0162  0.0182  0.0370  0.0162  0.0114
# ...           ...  ...     ...     ...     ...     ...     ...     ...
# L24106     0.0202  ...  0.0084  0.0223  0.0119  0.0230  0.0132  0.0209
# AJ419905   0.0188  ...  0.0087  0.0239  0.0130  0.0224  0.0123  0.0188
# U58504     0.0193  ...  0.0103  0.0227  0.0131  0.0220  0.0172  0.0172
# AF125591   0.0198  ...  0.0109  0.0205  0.0144  0.0274  0.0109  0.0164
# AF412977   0.0201  ...  0.0104  0.0194  0.0159  0.0221  0.0131  0.0201
#
#               TTC     TTG     TTT      CG
# ID
# AM084229   0.0100  0.0254  0.0161  0.5625
# KC196072   0.0082  0.0158  0.0034  0.5970
# FJ617539   0.0107  0.0287  0.0247  0.5446
# AJ318408   0.0101  0.0222  0.0128  0.5662
# NR_119012  0.0101  0.0249  0.0155  0.5645
# ...           ...     ...     ...     ...
# L24106     0.0077  0.0139  0.0119  0.4749
# AJ419905   0.0072  0.0174  0.0101  0.4729
# U58504     0.0083  0.0186  0.0083  0.4821
# AF125591   0.0082  0.0130  0.0068  0.4945
# AF412977   0.0069  0.0166  0.0083  0.4845
#
# [3479 rows x 71 columns]

# %% [markdown]
# # Сохраняем данные в формате csv

# %%
reset_sample = stratified_sampling.reset_index()
reset_sample
# Out:
#              ID    Domain          Phylum           Class             Order  \
# 0      AM084229  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# 1      KC196072  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# 2      FJ617539  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# 3      AJ318408  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# 4     NR_119012  Bacteria  Actinobacteria  Actinobacteria   Actinomycetales
# ...         ...       ...             ...             ...               ...
# 3474     L24106  Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# 3475   AJ419905  Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# 3476     U58504  Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# 3477   AF125591  Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
# 3478   AF412977  Bacteria     Tenericutes      Mollicutes  Mycoplasmoidales
#
#                     Family           Genus     AAA     AAC     AAG  ...  \
# 0         Actinomycetaceae          Winkia  0.0100  0.0161  0.0187  ...
# 1         Actinomycetaceae     Actinomyces  0.0089  0.0172  0.0185  ...
# 2         Actinomycetaceae         Gleimia  0.0100  0.0140  0.0187  ...
# 3         Actinomycetaceae      Mobiluncus  0.0108  0.0168  0.0182  ...
# 4         Actinomycetaceae          Winkia  0.0094  0.0162  0.0188  ...
# ...                    ...             ...     ...     ...     ...  ...
# 3474  Metamycoplasmataceae  Mycoplasmopsis  0.0279  0.0209  0.0251  ...
# 3475  Metamycoplasmataceae  Mycoplasmopsis  0.0246  0.0181  0.0224  ...
# 3476  Metamycoplasmataceae  Mycoplasmopsis  0.0220  0.0207  0.0220  ...
# 3477  Metamycoplasmataceae  Metamycoplasma  0.0192  0.0178  0.0253  ...
# 3478  Metamycoplasmataceae  Mycoplasmopsis  0.0208  0.0187  0.0249  ...
#
#          TCT     TGA     TGC     TGG     TGT     TTA     TTC     TTG     TTT  \
# 0     0.0087  0.0147  0.0187  0.0368  0.0161  0.0120  0.0100  0.0254  0.0161
# 1     0.0096  0.0185  0.0158  0.0357  0.0110  0.0082  0.0082  0.0158  0.0034
# 2     0.0140  0.0173  0.0187  0.0393  0.0173  0.0113  0.0107  0.0287  0.0247
# 3     0.0094  0.0155  0.0175  0.0370  0.0155  0.0101  0.0101  0.0222  0.0128
# 4     0.0087  0.0162  0.0182  0.0370  0.0162  0.0114  0.0101  0.0249  0.0155
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 3474  0.0084  0.0223  0.0119  0.0230  0.0132  0.0209  0.0077  0.0139  0.0119
# 3475  0.0087  0.0239  0.0130  0.0224  0.0123  0.0188  0.0072  0.0174  0.0101
# 3476  0.0103  0.0227  0.0131  0.0220  0.0172  0.0172  0.0083  0.0186  0.0083
# 3477  0.0109  0.0205  0.0144  0.0274  0.0109  0.0164  0.0082  0.0130  0.0068
# 3478  0.0104  0.0194  0.0159  0.0221  0.0131  0.0201  0.0069  0.0166  0.0083
#
#           CG
# 0     0.5625
# 1     0.5970
# 2     0.5446
# 3     0.5662
# 4     0.5645
# ...      ...
# 3474  0.4749
# 3475  0.4729
# 3476  0.4821
# 3477  0.4945
# 3478  0.4845
#
# [3479 rows x 72 columns]

# %%
reset_sample.to_csv('sampling_data.csv',
                           sep=';',
                           encoding='utf-8',
                           index=False)

# %% [markdown]
# # Сохраняем в формате dat
# ## Выбор CR/LF обсуловлен программой для дальнейшей обработки этих данных

# %%
reduced_dat = "reduced_" + dataset_name
with open(reduced_dat, 'w') as dat:
    dat.write(f"{reset_sample.shape[1]}\t{reset_sample.shape[0]}\n")
    for index, value in enumerate(reset_sample.columns):
        if index <= 6:
            dat.write(f"{value}\tSTRING\n")
        else:
            dat.write(f"{value}\tFLOAT\n")
reset_sample.to_csv(reduced_dat, sep='\t', mode='a', header=False, index=False, lineterminator='\r\n')

# %%
"\r\n"
# Out:
# '\r\n'
