# %%
import pandas as pd
import numpy as np

# %%
dataset_name = "rdp_16s_v18.fa.dat"
directory = %pwd
full_path =directory + '\\' + dataset_name

# %%
headers = []
with open(full_path) as datFile:
    datFile.readline()
    for _ in range(72):
        line = datFile.readline().split('\t')
        headers.append(line[0])

# %%
headers[1] = 'Domain' #домен
headers[2] = 'Phylum' #тип
headers[3] = 'Class' #класс
headers[4] = 'Order' #порядок
headers[5] = 'Family' #семейство
headers[6] = 'Genus' #род

# %%
frame = pd.read_csv(full_path, delimiter="\t", names=headers, skiprows=74)

# %% [markdown]
# <h1>Примеры строк из датасета</h1>

# %%
frame.sample(5)
# Out:
#              ID    Domain          Phylum                Class  \
# 13979  KR349442  Bacteria  Proteobacteria  Alphaproteobacteria
# 4252   EF422411  Bacteria      Firmicutes              Bacilli
# 13586  KJ632968  Bacteria  Proteobacteria  Gammaproteobacteria
# 15584  MN365231  Bacteria  Proteobacteria  Alphaproteobacteria
# 1728   AB327250  Bacteria  Actinobacteria       Actinobacteria
#
#                   Order             Family               Genus     AAA  \
# 13979   Rhodobacterales   Rhodobacteraceae        Celeribacter  0.0131
# 4252         Bacillales      Bacillaceae_1  Alkalihalobacillus  0.0150
# 13586    Pasteurellales    Pasteurellaceae        Ursidibacter  0.0147
# 15584   Rhodobacterales   Rhodobacteraceae     Sinirhodobacter  0.0137
# 1728   Catenulisporales  Catenulisporaceae       Catenulispora  0.0116
#
#           AAC     AAG  ...     TCT     TGA     TGC     TGG     TGT     TTA  \
# 13979  0.0207  0.0172  ...  0.0062  0.0221  0.0096  0.0248  0.0090  0.0145
# 4252   0.0190  0.0245  ...  0.0095  0.0211  0.0122  0.0252  0.0122  0.0122
# 13586  0.0170  0.0243  ...  0.0096  0.0206  0.0199  0.0258  0.0125  0.0133
# 15584  0.0173  0.0195  ...  0.0087  0.0202  0.0115  0.0252  0.0087  0.0115
# 1728   0.0191  0.0198  ...  0.0055  0.0136  0.0177  0.0279  0.0130  0.0061
#
#           TTC     TTG     TTT      CG
# 13979  0.0131  0.0096  0.0076  0.5499
# 4252   0.0088  0.0156  0.0054  0.5482
# 13586  0.0081  0.0184  0.0081  0.5169
# 15584  0.0137  0.0108  0.0043  0.5522
# 1728   0.0102  0.0123  0.0041  0.5936
#
# [5 rows x 72 columns]

# %% [markdown]
# <h1>Количество элементов в каждой группе микроорганизмов</h1>

# %%
by_domain = frame.groupby(['Phylum', 'Class', 'Order', 'Family'])
by_domain_count = by_domain.size().to_frame()
by_domain_count.rename(columns={0: 'Elements'}, inplace=True)
by_domain_count
# Out:
#                                                                                                   Elements
# Phylum                   Class                              Order             Family
# Abditibacteriota         Abditibacteria                     Abditibacteriales Abditibacteriaceae         1
# Acetothermia             Acetothermia_genera_incertae_sedis _                 _                          1
# Acidobacteria            Acidobacteria_Gp1                  Acidicapsa        _                          6
#                                                             Acidipila         _                          2
#                                                             Acidobacterium    _                          3
# ...                                                                                                    ...
# Woesearchaeota           Woesearchaeota_Incertae_Sedis_AR18 _                 _                          1
#                          Woesearchaeota_Incertae_Sedis_AR20 _                 _                          1
# candidate_division_WPS-1 WPS-1_genera_incertae_sedis        _                 _                          2
# candidate_division_WPS-2 WPS-2_genera_incertae_sedis        _                 _                          1
# candidate_division_ZB3   ZB3_genera_incertae_sedis          _                 _                          1
#
# [683 rows x 1 columns]

# %% [markdown]
# <h1>Статистические характеристики датасета</h1>

# %%
by_domain_count.describe()
# Out:
#           Elements
# count   683.000000
# mean     31.030747
# std      82.819738
# min       1.000000
# 25%       2.000000
# 50%       6.000000
# 75%      21.000000
# max    1135.000000

# %% [markdown]
# <h1>По умолчанию мы обрезаем все группы, количество элементов в которых меньше среднего значения</h1>
# <h2>Если вы хотите выбрать другой параметр - измените значение переменной reduce_factor, расположенной ниже</h2>

# %%
reduce_factor = by_domain_count['Elements'].mean()
reduce_factor
# Out:
# 31.0307467057101

# %%
reduce_groups = by_domain_count.loc[by_domain_count['Elements'] >= reduce_factor]
reduce_groups
# Out:
#                                                                                                Elements
# Phylum          Class               Order                                Family
# Acidobacteria   Acidobacteria_Gp1   Gp1                                  _                           38
#                 Acidobacteria_Gp3   Gp3                                  _                           34
#                 Acidobacteria_Gp6   Gp6                                  _                           57
# Actinobacteria  Actinobacteria      Actinomycetales                      Actinomycetaceae            96
#                                     Bifidobacteriales                    Bifidobacteriaceae         111
# ...                                                                                                 ...
# Proteobacteria  Gammaproteobacteria Xanthomonadales                      Xanthomonadaceae           212
# Spirochaetes    Spirochaetia        Spirochaetales                       Spirochaetaceae             93
# Tenericutes     Mollicutes          Entomoplasmatales                    Spiroplasmataceae           50
#                                     Mycoplasmoidales                     Metamycoplasmataceae       122
# Verrucomicrobia Spartobacteria      Spartobacteria_genera_incertae_sedis _                           32
#
# [137 rows x 1 columns]

# %%
by_domain_count.to_excel(directory + "\\" + "groups.xlsx", 'Sheet1')

# %%
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <h1>

# %%
frame.groupby(['Phylum', 'Class', 'Order', 'Family']).filter(lambda group: len(group) > reduce_factor )
# Out:
#               ID    Domain          Phylum                Class  \
# 0       EF599163  Bacteria  Proteobacteria  Gammaproteobacteria
# 1       AY859683  Bacteria  Actinobacteria       Actinobacteria
# 2       AY883036  Bacteria  Proteobacteria  Alphaproteobacteria
# 3       DQ656489  Bacteria  Proteobacteria   Betaproteobacteria
# 4         D85479  Bacteria  Actinobacteria       Actinobacteria
# ...          ...       ...             ...                  ...
# 21188  NR_074344  Bacteria  Actinobacteria       Actinobacteria
# 21189  NR_074339  Bacteria   Bacteroidetes           Cytophagia
# 21191  NR_074244  Bacteria  Proteobacteria  Alphaproteobacteria
# 21192  NR_074234  Bacteria   Bacteroidetes          Bacteroidia
# 21193  NR_044194  Bacteria  Actinobacteria       Actinobacteria
#
#                    Order               Family              Genus     AAA  \
# 0            Vibrionales         Vibrionaceae             Vibrio  0.0150
# 1        Mycobacteriales     Mycobacteriaceae      Mycobacterium  0.0101
# 2       Rhodospirillales     Acetobacteraceae        Acetobacter  0.0095
# 3        Burkholderiales       Comamonadaceae          Aquincola  0.0152
# 4      Micromonosporales   Micromonosporaceae      Couchioplanes  0.0136
# ...                  ...                  ...                ...     ...
# 21188    Mycobacteriales   Corynebacteriaceae    Corynebacterium  0.0107
# 21189       Cytophagales        Cytophagaceae            Runella  0.0127
# 21191        Rhizobiales  Methylobacteriaceae   Methylobacterium  0.0102
# 21192      Bacteroidales   Porphyromonadaceae      Porphyromonas  0.0136
# 21193  Pseudonocardiales   Pseudonocardiaceae  Saccharomonospora  0.0112
#
#           AAC     AAG  ...     TCT     TGA     TGC     TGG     TGT     TTA  \
# 0      0.0176  0.0209  ...  0.0052  0.0202  0.0183  0.0248  0.0144  0.0104
# 1      0.0176  0.0196  ...  0.0054  0.0142  0.0176  0.0318  0.0149  0.0061
# 2      0.0154  0.0212  ...  0.0066  0.0220  0.0139  0.0308  0.0190  0.0088
# 3      0.0179  0.0214  ...  0.0062  0.0186  0.0200  0.0255  0.0117  0.0097
# 4      0.0170  0.0218  ...  0.0068  0.0143  0.0150  0.0252  0.0116  0.0061
# ...       ...     ...  ...     ...     ...     ...     ...     ...     ...
# 21188  0.0168  0.0195  ...  0.0060  0.0141  0.0174  0.0322  0.0154  0.0087
# 21189  0.0161  0.0268  ...  0.0054  0.0174  0.0188  0.0255  0.0114  0.0121
# 21191  0.0163  0.0197  ...  0.0068  0.0183  0.0142  0.0299  0.0075  0.0102
# 21192  0.0197  0.0204  ...  0.0054  0.0244  0.0177  0.0143  0.0102  0.0136
# 21193  0.0154  0.0189  ...  0.0063  0.0168  0.0161  0.0307  0.0140  0.0070
#
#           TTC     TTG     TTT      CG
# 0      0.0078  0.0150  0.0065  0.5394
# 1      0.0095  0.0142  0.0054  0.5796
# 2      0.0088  0.0147  0.0073  0.5545
# 3      0.0055  0.0131  0.0062  0.5686
# 4      0.0102  0.0116  0.0054  0.6014
# ...       ...     ...     ...     ...
# 21188  0.0107  0.0154  0.0080  0.5680
# 21189  0.0074  0.0141  0.0107  0.5224
# 21191  0.0088  0.0129  0.0081  0.5752
# 21192  0.0102  0.0163  0.0075  0.5302
# 21193  0.0091  0.0112  0.0014  0.5955
#
# [17587 rows x 72 columns]

# %%
temp = frame.groupby(['Phylum', 'Class', 'Order', 'Family'])['ID'].count().to_frame(name = 'count').reset_index()
temp
# Out:
#                        Phylum                               Class  \
# 0            Abditibacteriota                      Abditibacteria
# 1                Acetothermia  Acetothermia_genera_incertae_sedis
# 2               Acidobacteria                   Acidobacteria_Gp1
# 3               Acidobacteria                   Acidobacteria_Gp1
# 4               Acidobacteria                   Acidobacteria_Gp1
# ..                        ...                                 ...
# 678            Woesearchaeota  Woesearchaeota_Incertae_Sedis_AR18
# 679            Woesearchaeota  Woesearchaeota_Incertae_Sedis_AR20
# 680  candidate_division_WPS-1         WPS-1_genera_incertae_sedis
# 681  candidate_division_WPS-2         WPS-2_genera_incertae_sedis
# 682    candidate_division_ZB3           ZB3_genera_incertae_sedis
#
#                  Order              Family  count
# 0    Abditibacteriales  Abditibacteriaceae      1
# 1                    _                   _      1
# 2           Acidicapsa                   _      6
# 3            Acidipila                   _      2
# 4       Acidobacterium                   _      3
# ..                 ...                 ...    ...
# 678                  _                   _      1
# 679                  _                   _      1
# 680                  _                   _      2
# 681                  _                   _      1
# 682                  _                   _      1
#
# [683 rows x 5 columns]

# %%
temp.to_excel(directory + "\\" + "groups.xlsx", 'All_groups')

# %%
f
